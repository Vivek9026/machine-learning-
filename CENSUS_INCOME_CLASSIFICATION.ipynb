# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/census-income_ (1).csv")

# %%
df.head()
# Out:
#    age          workclass   fnlwgt   education   education-num  \
# 0   39          State-gov    77516   Bachelors              13
# 1   50   Self-emp-not-inc    83311   Bachelors              13
# 2   38            Private   215646     HS-grad               9
# 3   53            Private   234721        11th               7
# 4   28            Private   338409   Bachelors              13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#     capital-gain   capital-loss   hours-per-week  native-country Unnamed: 14
# 0           2174              0               40   United-States       <=50K
# 1              0              0               13   United-States       <=50K
# 2              0              0               40   United-States       <=50K
# 3              0              0               40   United-States       <=50K
# 4              0              0               40            Cuba       <=50K

# %%
df.columns
# Out:
# Index(['age', ' workclass', ' fnlwgt', ' education', ' education-num',
#        ' marital-status', ' occupation', ' relationship', ' race', ' sex',
#        ' capital-gain', ' capital-loss', ' hours-per-week', ' native-country',
#        'Unnamed: 14'],
#       dtype='object')

# %% [markdown]
# ### REPLACE THE WHITE SPACES FROM THE COLUMNS NAMES

# %%
df.columns = df.columns.str.replace(' ','')

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'Unnamed:14'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace("-",".")

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'Unnamed:14'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# Unnamed:14        0
# dtype: int64

# %%
df.describe()
# Out:
#                 age        fnlwgt  education.num  capital.gain  capital.loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours.per.week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
#DATA MANIPULATION
#Extractracting the “education” column and store it in “census_ed” .

census_ed = df[['education']]

# %%
census_ed.head()
# Out:
#     education
# 0   Bachelors
# 1   Bachelors
# 2     HS-grad
# 3        11th
# 4   Bachelors

# %%
#) Extracting all the columns from “age” to “relationship” and store it in “census_seq”.
census_seq = df.iloc[:,0:8]

census_seq.head()
# Out:
#    age          workclass  fnlwgt   education  education.num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital.status          occupation    relationship
# 0        Never-married        Adm-clerical   Not-in-family
# 1   Married-civ-spouse     Exec-managerial         Husband
# 2             Divorced   Handlers-cleaners   Not-in-family
# 3   Married-civ-spouse   Handlers-cleaners         Husband
# 4   Married-civ-spouse      Prof-specialty            Wife

# %%
#Extract the column number “0”, “5”, “6” and store it in “census_col”.

census_col = df.iloc[:,[0,5,6]]

# %%
census_col.head()
# Out:
#    age       marital.status          occupation
# 0   39        Never-married        Adm-clerical
# 1   50   Married-civ-spouse     Exec-managerial
# 2   38             Divorced   Handlers-cleaners
# 3   53   Married-civ-spouse   Handlers-cleaners
# 4   28   Married-civ-spouse      Prof-specialty

# %%
df['workclass'].value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: workclass, dtype: int64

# %%
#) Extracting all the male employees who work in state-gov and store it in “male_gov”.

male_gov=df[(df['workclass']=='State-gov') & (df['sex']=='Male')]

# %%
#Extract all the 39 year olds who either have a bachelor's degree or who are native of the United States and store the result in “census_us”.
#We are writing a condition where age should be 39 and storing it in census. This condition is then taken and applied on the
#next one to get the result.

census=df[(df['age']==39)]

# %%
census_us=census[(census['education']=='Bachelors') | (census['native.country']==' United-States')]
census_us.head()
# Out:
#      age          workclass  fnlwgt      education  education.num  \
# 0     39          State-gov   77516      Bachelors             13
# 28    39            Private  367260        HS-grad              9
# 129   39            Private  365739   Some-college             10
# 166   39        Federal-gov  235485     Assoc-acdm             12
# 320   39   Self-emp-not-inc  174308        HS-grad              9
#
#           marital.status        occupation    relationship    race    sex  \
# 0          Never-married      Adm-clerical   Not-in-family   White   Male
# 28              Divorced   Exec-managerial   Not-in-family   White   Male
# 129             Divorced      Craft-repair   Not-in-family   White   Male
# 166        Never-married   Exec-managerial   Not-in-family   White   Male
# 320   Married-civ-spouse   Exec-managerial         Husband   White   Male
#
#      capital.gain  capital.loss  hours.per.week  native.country Unnamed:14
# 0            2174             0              40   United-States      <=50K
# 28              0             0              80   United-States      <=50K
# 129             0             0              40   United-States      <=50K
# 166             0             0              42   United-States      <=50K
# 320             0             0              40   United-States      <=50K

# %%
#sample() helps us to get random rows
# to select 200 random rows
census_200=df.sample(200)
census_200
# Out:
#        age          workclass  fnlwgt      education  education.num  \
# 22409   27          State-gov  230922        Masters             14
# 30111   41        Federal-gov  219155    Prof-school             15
# 14019   45            Private  174426        HS-grad              9
# 12561   45            Private  190088        HS-grad              9
# 3214    22            Private  190625   Some-college             10
# ...    ...                ...     ...            ...            ...
# 9032    46          Local-gov  141058        HS-grad              9
# 28526   28            Private  124680        HS-grad              9
# 16094   31            Private  236599      Bachelors             13
# 27407   31            Private   50276      Bachelors             13
# 1168    88   Self-emp-not-inc  206291    Prof-school             15
#
#                marital.status        occupation    relationship    race  \
# 22409           Never-married   Exec-managerial   Not-in-family   White
# 30111      Married-civ-spouse    Prof-specialty         Husband   White
# 14019      Married-civ-spouse      Craft-repair         Husband   White
# 12561   Married-spouse-absent      Adm-clerical       Unmarried   White
# 3214            Never-married      Adm-clerical       Own-child   White
# ...                       ...               ...             ...     ...
# 9032       Married-civ-spouse   Exec-managerial         Husband   White
# 28526           Never-married             Sales       Unmarried   White
# 16094      Married-civ-spouse   Exec-managerial         Husband   White
# 27407                Divorced    Prof-specialty   Not-in-family   White
# 1168       Married-civ-spouse    Prof-specialty         Husband   White
#
#            sex  capital.gain  capital.loss  hours.per.week  native.country  \
# 22409     Male             0             0              40        Scotland
# 30111     Male             0             0              50           India
# 14019     Male             0             0              40   United-States
# 12561   Female             0             0              30   United-States
# 3214      Male             0             0              35   United-States
# ...        ...           ...           ...             ...             ...
# 9032      Male             0             0              65   United-States
# 28526   Female             0             0              70   United-States
# 16094     Male             0             0              45   United-States
# 27407     Male             0             0              60   United-States
# 1168      Male             0             0              40   United-States
#
#       Unnamed:14
# 22409      <=50K
# 30111       >50K
# 14019      <=50K
# 12561      <=50K
# 3214       <=50K
# ...          ...
# 9032       <=50K
# 28526      <=50K
# 16094       >50K
# 27407      <=50K
# 1168       <=50K
#
# [200 rows x 15 columns]

# %%
#Getting the count of different levels of the “workclass” column.
#value_counts() helps us to get the total count of all elements present in a particular column.
df[['workclass']].value_counts()
# Out:
# workclass
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# dtype: int64

# %%
#Here we are calculating the mean of capital gain on the bases of work class
# calculate the mean of capital.gain grouped according to workclass

df.groupby(['workclass'])['capital.gain'].mean()
# Out:
# workclass
#  ?                    606.795752
#  Federal-gov          833.232292
#  Local-gov            880.202580
#  Never-worked           0.000000
#  Private              889.217792
#  Self-emp-inc        4875.693548
#  Self-emp-not-inc    1886.061787
#  State-gov            701.699538
#  Without-pay          487.857143
# Name: capital.gain, dtype: float64

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'Unnamed:14'],
#       dtype='object')

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education.num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital.status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital.gain  capital.loss  hours.per.week  native.country Unnamed:14
# 0          2174             0              40   United-States      <=50K
# 1             0             0              13   United-States      <=50K
# 2             0             0              40   United-States      <=50K
# 3             0             0              40   United-States      <=50K
# 4             0             0              40            Cuba      <=50K

# %%
income=df["Unnamed:14"]
df["income"]=income
df.head()
# Out:
#    age          workclass  fnlwgt   education  education.num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital.status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital.gain  capital.loss  hours.per.week  native.country Unnamed:14  \
# 0          2174             0              40   United-States      <=50K
# 1             0             0              13   United-States      <=50K
# 2             0             0              40   United-States      <=50K
# 3             0             0              40   United-States      <=50K
# 4             0             0              40            Cuba      <=50K
#
#    income
# 0   <=50K
# 1   <=50K
# 2   <=50K
# 3   <=50K
# 4   <=50K

# %%
df['income'].value_counts()
# Out:
#  <=50K    24720
#  >50K      7841
# Name: income, dtype: int64

# %%
df=pd.DataFrame(df)
df.drop("Unnamed:14",axis=1,inplace=True)
df.head()
# Out:
#    age          workclass  fnlwgt   education  education.num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital.status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital.gain  capital.loss  hours.per.week  native.country  income
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %%
# Calculating the percentage of married people in the census data.
df['marital.status'].value_counts()
# Out:
#  Married-civ-spouse       14976
#  Never-married            10683
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: marital.status, dtype: int64

# %%
#calculating % of married people
total=len(df['marital.status'])
married=14976+418+23
precen_mar=(married/total)*100
precen_mar
# Out:
# 47.34805442093302

# %%
#Calculatig the percentage of high school graduates earning more than 50,000 annually
df['education'].value_counts()
# Out:
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5355
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: education, dtype: int64

# %% [markdown]
# #LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
lo=LogisticRegression()

# %%
df[['occupation']].value_counts()
# Out:
# occupation
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3770
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# dtype: int64

# %%
#occupation is indpendent

x=df['occupation']
x=pd.DataFrame(x)

# %%
# giving particular labels to the elements in my columns
L=LabelEncoder()

# %%
x=L.fit_transform(x)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
x = pd.DataFrame(x)

# %%
x.head()
# Out:
#     0
# 0   1
# 1   4
# 2   6
# 3   6
# 4  10

# %%
y=df['income'].replace('<=50K',0).replace('>50K',1)

# %%
y.value_counts()
# Out:
#  <=50K    24720
#  >50K      7841
# Name: income, dtype: int64

# %%
len(y)
# Out:
# 32561

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.35,random_state=1)

# %%
lo.fit(x_train,y_train)   #trained our model
y_pred=lo.predict(x_test)  #predicting by our model

# %%
print('confusion_matrix :')
print(confusion_matrix(y_pred,y_test))
print('accuracy_score :',accuracy_score(y_test,y_pred))
# Out:
# confusion_matrix :
# [[8800 2597]
#  [   0    0]]
# accuracy_score : 0.7721330174607353

# %%
#TP TN
#FP FN

# %%
#PRECISION  = TP/TP+FP
#RECALL     = TP/ TP+ FN
#F-1 SCORE  = WEIGHTED HARMOINC MEAN
#SUPPORT = NO.OF ITEMS IN DATASET.

# %%
#TP - TRUE POSITIVE

#TN - TRUE NEGATIVE

#FN - FALSE NEGATIVE   TYPE 1 ERROR

#FP - FALSE POSITIVE   TYPE II ERROR

# %% [markdown]
# #DECISION TREE MODEL

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education.num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital.status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital.gain  capital.loss  hours.per.week  native.country  income
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %%
# feauture engineering

# %%
df['education'].value_counts()
# Out:
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5355
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: education, dtype: int64

# %%
df.education = df.education.replace(['Preschool','1st-4th','5th-6th','7th-8th','9th','10th','11th','12th'],'School')

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education.num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital.status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital.gain  capital.loss  hours.per.week  native.country  income
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %%
df.education = df.education.replace(['Assoc-voc', 'Assoc-acdm', 'Prof-school', 'Some-college'], 'Higher')
df['marital.status']= df['marital.status'].replace(['Married-civ-spouse', 'Married-AF-spouse'], 'married')
df['marital.status']= df['marital.status'].replace(['Never-married'], 'not-married')
df['marital.status']= df['marital.status'].replace(['Divorced', 'Separated','Widowed','Married-spouse-absent'], 'other')
df.income = df.income.replace('<=50K', 0)
df.income = df.income.replace('>50K', 1)

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'income'],
#       dtype='object')

# %%
b = len(df[(df['income']==1)])

# %%
a = len(df['income'])

# %%
(b/a)*100
# Out:
# 24.080955744602438

# %%
df = df.apply(L.fit_transform)    #encoding or changing the categroical into numrical value

# %%
df.head()
# Out:
#    age  workclass  fnlwgt  education  education.num  marital.status  \
# 0   22          7    2671          9             12               4
# 1   33          6    2926          9             12               2
# 2   21          4   14086         11              8               0
# 3   36          4   15336          1              6               2
# 4   11          4   19355          9             12               2
#
#    occupation  relationship  race  sex  capital.gain  capital.loss  \
# 0           1             1     4    1            25             0
# 1           4             0     4    1             0             0
# 2           6             1     4    1             0             0
# 3           6             0     2    1             0             0
# 4          10             5     2    0             0             0
#
#    hours.per.week  native.country  income
# 0              39              39       0
# 1              12              39       0
# 2              39              39       0
# 3              39              39       0
# 4              39               5       0

# %%
#independent
x=df.iloc[:,:-1]
#dependent
y=df.iloc[:,-1]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=1)
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)  # model building
y_pred=dt.predict(x_test) # prediction by our model

# %%
print('confusion_matrix :')
print(confusion_matrix(y_pred,y_test))
print('accuracy_score :',accuracy_score(y_test,y_pred))
# Out:
# confusion_matrix :
# [[6544  854]
#  [1006 1365]]
# accuracy_score : 0.8096018016173611

# %% [markdown]
# #RANDOM FOREST MODEL

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=1)
rf=RandomForestClassifier(n_estimators=300)
rf.fit(x_train,y_train)
y_pred=rf.predict(x_test)

# %%
print('confusion_matrix :')
print(confusion_matrix(y_pred,y_test))
print('accuracy_score :',accuracy_score(y_test,y_pred))
# Out:
# confusion_matrix :
# [[4661  522]
#  [ 365  965]]
# accuracy_score : 0.8638108398587441

# %% [markdown]
# # conclusions
#
# # we have discussed all the classification models
# # in which we have got the random forest as the best classifier
# #because the accuracy is like in ascending order log_reg<des_tree<rand_forst
